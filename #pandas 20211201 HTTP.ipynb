# %%
pip install --upgrade requests
# Out:
# Requirement already satisfied: requests in c:\users\jitae\appdata\local\programs\python\python39\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jitae\appdata\local\programs\python\python39\lib\site-packages (from requests) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jitae\appdata\local\programs\python\python39\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jitae\appdata\local\programs\python\python39\lib\site-packages (from requests) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jitae\appdata\local\programs\python\python39\lib\site-packages (from requests) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
simple_text_url = "http://itpaper.co.kr/data/simple_text.txt"

# %%
r = requests.get(simple_text_url)
r #상태코드 출력
# Out:
# <Response [200]>

# %%
if r.status_code !=200:
    err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
    raise Exception(err_msg)

# %%
r.encoding = "utf-8"
print(r.text)
# Out:
# Hello Python~!!!
# 안녕하세요. 파이썬~!!!

# %%
#2
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"

r = requests.get("https://datalab.naver.com/",
                 headers={'User-agent': user_agent, 'referer': None})

if r.status_code != 200:
    err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
    raise Exception(err_msg)
    
r.encoding = "utf-8"
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=1200">\n    <title>네이버 데이터랩</title>\n    \n    <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.datalab/202108110516/css/datalab.css">\n    <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.datalab/202108110516/css/graph.css">\n\n    <link rel="icon" sizes="192x192" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/android_legacy_xxxhpdi_192x192.png" >\n    <link rel="icon" sizes="144x144" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/android_legacy_xxhpdi_144x144.png" >\n    <link rel="icon" sizes="96x96" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/android_legacy_xhdpi_96x96.png" >\n    <link rel="icon" sizes="72x72" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/android_legacy_hdpi_72X72.png" >\n\n    <link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/iOS_iPhone@3x_180X180.png">\n    <link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/iOS_iPadPro@2x_167X167.png">\n    <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/iOS_iPad@2x_152X152.png">\n    <link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://ssl.pstatic.net/static.datalab/202108110516/img/favicon/iOS_iPhone@2x_120X120.png">\n    \n    \n    <meta property="og:title" content="네이버 데이터랩"/>\n    <meta property="og:url" content="https://datalab.naver.com/"/>\n    <meta property="og:image" content="https://ssl.pstatic.net/static.datalab/img2019/datalab_og_244x244.jpg"/>\n    <meta property="og:description" content="네이버의 검색 트렌드 및 급상승검색어 이력, 쇼핑 카테고리별 검색 트렌드 제공"/>\n    <meta name="description" content="네이버의 검색 트렌드 및 급상승검색어 이력, 쇼핑 카테고리별 검색 트렌드 제공">\n\n</head>\n\n<!--[if lte IE 9]>\n<body class="pop_opened">\n<![endif]-->\n\n<![if !IE]>\n<body>\n<![endif]>\n\n<div id="u_skip">\n    <a href="#content"><span>본문으로 바로가기</span></a>\n</div>\n<div id="wrap" class="wrap">\n    <div id="header" class="header">\n        <div class="inner">\n            <div class="srch_wrap">\n                <a href="https://www.naver.com" target="_blank" class="logo_area">\n                    <span class="sp_header_logo"><span class="blind">NAVER</span></span>\n                </a>\n                <h1 class="sta_area">\n                    <a href="/" class="sp_sta"><span class="blind">DataLab</span></a>\n                </h1>\n            </div>\n            <div class="gnb_wrap">\n                <div id="gnb"></div>\n            </div>\n        </div>\n        <div id="lnb" class="lnb">\n            <div class="lnb_innner">\n                <ul class="lnb_list">\n                    <li class="list _home active">\n                        <a href="/" class="list_area">\n                        <span class="sp_lnb_list nav1">\n                            <span class="blind">데이터랩 홈</span>\n                        </span>\n                        </a>\n                    </li>\n                    <li class="list _keyword ">\n                        <a href="/keyword/trendSearch.naver" class="list_area">\n                        <span class="sp_lnb_list nav3">\n                            <span class="blind">검색어트렌드</span>\n                        </span>\n                        </a>\n                    </li>\n                    <li class="list _shopping ">\n                        <a href="/shoppingInsight/sCategory.naver" class="list_area">\n\t\t\t\t\t\t\t<span class="sp_lnb_list nav4">\n\t\t\t\t\t\t\t\t<span class="blind">쇼핑인사이트</span>\n\t\t\t\t\t\t\t</span>\n                        </a>\n                    </li>\n                    <li cla ...

# %%
file_url = "http://itpaper.co.kr/data/sample.png"

r = requests.get(file_url,
                headers={'User-agent': user_agent, 'referer': None},
                stream = True)

if r.status_code != 200:
    err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
    raise Exception(err_msg)
