# %%
from matplotlib import pyplot
value = [50, 80, 90, 20, 50, 70]
pyplot.pie(value)
# Out:
# ([<matplotlib.patches.Wedge at 0x23693b5b460>,
# ...
#  [Text(0.9969385560680448, 0.4648801086570193, ''),
#   Text(-5.149471629032507e-08, 1.0999999999999988, ''),
#   Text(-1.0958141728876523, 0.09587126002379803, ''),
#   Text(-0.7070663257291676, -0.8426489251282855, ''),
#   Text(-0.09587123437441601, -1.0958141751316808, ''),
#   Text(0.9010673159946853, -0.6309339839049203, '')])

# %%
from matplotlib import pyplot

pyplot.rcParams["font.family"] = 'NanumGothic'
pyplot.rcParams["font.size"] = 12
pyplot.rcParams["figure.figsize"] = (10, 10)

ratio = [3700,2800,1300,590,600]
labels = ['Apple', '삼성', 'LG', 'Sony', '기타']
colors = ['#ff0000','#0066ff','#ff00ff','#00ffff','#ffff00']
explode = [0.0, 0.0, 0.0, 0.15, 0.1] #튀어나오게 설정

pyplot.figure()

pyplot.title('스마트폰 점유율')
pyplot.pie(ratio, labels=labels, colors=colors, explode=explode,
          autopct='%0.2f%%', shadow=False, startangle=190)

pyplot.show()
pyplot.close()

# %%
csv_list = None
with open("smkfail.csv", "r", encoding='euc-kr') as f:
    csv_list = f.readlines()
print(csv_list)

from matplotlib import pyplot

pyplot.rcParams["font.family"] = 'NanumGothic'
pyplot.rcParams["font.size"] = 15
pyplot.rcParams["figure.figsize"] = (12, 12)

labels = ['스트레스', '기타', '타인의 유혹', '금단증세',
          '기존에 피우던 습관']
ratio = [59.3,0.1,3.9,8.4,28.3]
colors = ['#ff0000','#0066ff','#ff00ff','#ffff00','#ff7575']
explode = [0.0, 0.12, 0.07, 0.04, 0.0] #튀어나오게 설정

pyplot.figure()

pyplot.title('경기 30~39세 남성의 재흡연 사유')
pyplot.pie(ratio, labels=labels, colors=colors, explode=explode,
          autopct='%0.1f%%', shadow=False, startangle=235)

pyplot.show()
pyplot.close()
# Out:
# ['행정구역,스트레스,타인의 유혹,금단증세,기존에 피우던 습관,기타 등\n', '경기,59.3,3.9,8.4,28.3,0.1\n']

# %% [markdown]
# # 산점도 그래프

# %%
from matplotlib import pyplot
from sample import tmp
from sample import qty

pyplot.rcParams["font.family"] = 'NanumGothic'
pyplot.rcParams["font.size"] = 12
pyplot.rcParams["figure.figsize"] = (10, 10)

pyplot.figure()

pyplot.scatter(tmp, qty, color='#ff6600', marker='>', label='판매량')
pyplot.legend()
pyplot.grid()
pyplot.title('기온과 아이스크림 판매량의 관계')
pyplot.ylabel('아이스크림 판매량')
pyplot.xlabel('기온')

pyplot.show()
pyplot.close()

# %%
smkage = None
with open("smkage.csv", "r", encoding = 'euc-kr') as f:
    smkage = f.readlines()
print(smkage)

age = ["19-29세","30-39세","40-49세","50-59세","60-69세","70세 이상"]
pct = [37.8,39.2,37.9,36.7,30.1,17]

from matplotlib import pyplot

pyplot.rcParams["font.family"] = 'NanumGothic'
pyplot.rcParams["font.size"] = 12
pyplot.rcParams["figure.figsize"] = (10, 10)

pyplot.figure()

pyplot.scatter(age, pct, color='#ff6600', marker='*', label='흡연률')
pyplot.legend()
pyplot.title('나이와 흡연률의 상관관계')
pyplot.ylabel('흡연률')
pyplot.xlabel('나이')

pyplot.show()
pyplot.close()
# Out:
# ['연령별,19-29세,30-39세,40-49세,50-59세,60-69세,70세 이상\n', '분율,37.8,39.2,37.9,36.7,30.1,17\n']
